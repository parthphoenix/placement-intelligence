# %% [markdown]
# # 01 – Exploratory Data Analysis
# Run the full EDA from the src module:
# ```python
# from src.eda import run_eda
# run_eda()
# ```

# %%
import sys; sys.path.insert(0, '..')
from src.eda import run_eda
run_eda()
